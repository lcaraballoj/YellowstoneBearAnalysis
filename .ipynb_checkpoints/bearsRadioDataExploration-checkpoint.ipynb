# %%
import pandas as pd
import numpy as np
import matplotlib.pylab as plt
import seaborn as sns
plt.style.use('ggplot')

# %%
bearsRadio = pd.read_csv('bearRadio.csv')

# %%
bearsRadio.shape
# Out:
# (2272, 9)

# %%
bearsRadio.head(5)
# Out:
#    Bear     Sex    Age            Offspring Out of den Into den  \
# 0   314    Male  Adult                  NaN         No       No
# 1   373    Male  Adult                  NaN         No      Yes
# 2   409  Female  Adult  3 yearlings, 1 lost        Yes       No
# 3   419    Male  Adult                  NaN         No      Yes
# 4   424    Male  Adult                  NaN        Yes       No
#
#         Current status Transported  Year
# 0  Vehicle strike-dead         NaN  2022
# 1               Active         NaN  2022
# 2                 Cast         NaN  2022
# 3               Active         NaN  2022
# 4                 Cast         NaN  2022

# %%
bearsRadio.columns
# Out:
# Index(['Bear', 'Sex', 'Age', 'Offspring', 'Out of den', 'Into den',
#        'Current status', 'Transported', 'Year'],
#       dtype='object')

# %%
bearsRadio.dtypes
# Out:
# Bear               int64
# Sex               object
# Age               object
# Offspring         object
# Out of den        object
# Into den          object
# Current status    object
# Transported       object
# Year               int64
# dtype: object

# %%
bearsRadio.isna().sum()
# Out:
# Bear                 0
# Sex                  0
# Age                  2
# Offspring         1770
# Out of den           1
# Into den            12
# Current status       0
# Transported       2037
# Year                 0
# dtype: int64

# %%
bearsRadio = bearsRadio.drop('Transported', axis=1) # Remove transported column

# %%
pd.DataFrame(bearsRadio['Year'].value_counts())
# Out:
#       count
# Year
# 2021    120
# 2022    112
# 2012    112
# 2017    111
# 2018    106
# 2016    106
# 2020    104
# 2015    101
# 2013     99
# 2019     98
# 2006     92
# 2011     92
# 2005     91
# 2009     91
# 2008     87
# 2007     86
# 2010     85
# 2000     84
# 2001     82
# 2002     81
# 2003     80
# 2004     78
# 1999     65
# 1998     58
# 2014     51

# %% [markdown]
# Note that in the year 2020 we have the most radio bears recorded.

# %% [markdown]
# ## Radio in the Den and Out of the Den

# %%
pd.DataFrame(bearsRadio['Into den'].value_counts()) # Number of bears who have a radio when entering den
# Out:
#           count
# Into den
# Yes        1298
# No          954
# ?             7
# Yes?          1

# %% [markdown]
# We can so that many bears enter their den with their radio on. Let us see how many bears have a radio when leaving their den and the ratio that happens between bears who enter their den and leave their den with the radio attached.

# %%
pd.DataFrame(bearsRadio['Out of den'].value_counts())
# Out:
#             count
# Out of den
# Yes          1158
# No           1112
# Yes??           1

# %%
len(bearsRadio[(bearsRadio['Into den']=='Yes') & (bearsRadio['Out of den']=='Yes')])
# Out:
# 527

# %%
len(bearsRadio[(bearsRadio['Into den']=='Yes') & (bearsRadio['Out of den']=='No')])
# Out:
# 771

# %% [markdown]
# Note that most bears who enter their den with the radio will no longer have the radio when the leave they den.

# %% [markdown]
# ## Current Status

# %%
pd.DataFrame(bearsRadio['Current status'].value_counts())
# Out:
#                           count
# Current status
# Active                     1161
# Cast                        677
# active                      137
# Dead                         59
# Removed                      57
# Missing                      48
# Killed                       17
# Probable battery failure     11
# Unresolved                   10
# cast collar                   8
# dead                          8
# missing                       8
# Unresolvedb                   7
# Battery failure               6
# Died                          4
# removed                       4
# killed                        4
# battery failed                3
# unresolved                    3
# Den/Cast?                     3
# Battery                       3
# Unknown                       3
# collar on mortality           3
# Failed transmitter            3
# Failed battery                2
# Den/cast?                     2
# Cast/Dead?                    2
# Cast - removed                2
# dead (mgt removal)            2
# Unresolveda                   1
# b Cast                        1
# dead (old age)                1
# Probable failed battery       1
# Vehicle strike-dead           1
# Failed transmitter/Cast       1
# Cast/Dead                     1
# Unexplained Loss              1
# Live removal                  1
# Cast/dead?                    1
# Cast/removed                  1
# Cast - died                   1
# Cast - Died                   1
# Cast - killed                 1
# missing (dispersing)          1

# %% [markdown]
# We can see that there are repeated answers in our column which are marked as different for various reasons such as mispellings and cases of the words. In the data cleansing stage we will combine as many as possible.

# %%
bearsRadio.loc[bearsRadio.duplicated(subset=['Bear'])]
# Out:
#       Bear     Sex       Age    Offspring Out of den Into den Current status  \
# 112    373    Male     Adult          NaN        Yes       No           Cast
# 114    409  Female     Adult       3 cubs        Yes      Yes         Active
# 115    424    Male     Adult          NaN         No      Yes         Active
# 116    460    Male     Adult          NaN        Yes      Yes         Active
# 117    476  Female     Adult  1 cub, lost         No      Yes         Active
# ...    ...     ...       ...          ...        ...      ...            ...
# 2267   321  Female     Adult         none         No      Yes         active
# 2268   322  Female  Subadult          NaN         No      Yes         active
# 2269   323    Male  Subadult          NaN         No      Yes         active
# 2270   324    Male  Subadult          NaN         No      Yes         active
# 2271   325  Female  Subadult          NaN         No      Yes         active
#
#       Year
# 112   2021
# 114   2021
# 115   2021
# 116   2021
# 117   2021
# ...    ...
# 2267  1998
# 2268  1998
# 2269  1998
# 2270  1998
# 2271  1998
#
# [1428 rows x 8 columns]

# %%
pd.DataFrame(bearsRadio['Bear'].value_counts()).plot(kind='bar', figsize=(40,10)) # Visual Representation of handler captures
# Out:
# <AxesSubplot:xlabel='Bear'>

# %%
bearsRadio.query('Bear == 373')
# Out:
#       Bear   Sex       Age Offspring Out of den Into den Current status  Year
# 1      373  Male     Adult       NaN         No      Yes         Active  2022
# 112    373  Male     Adult       NaN        Yes       No           Cast  2021
# 232    373  Male     Adult       NaN         No      Yes         Active  2020
# 917    373  Male     Adult       NaN        Yes       No           Cast  2013
# 1018   373  Male     Adult       NaN         No      Yes         active  2012
# 1312   373  Male     Adult       NaN        Yes       No           Cast  2009
# 1400   373  Male     Adult       NaN        Yes      Yes         Active  2008
# 1486   373  Male     Adult       NaN         No      Yes         Active  2007
# 1575   373  Male     Adult       NaN        Yes       No           Cast  2006
# 1665   373  Male     Adult       NaN         No      Yes         Active  2005
# 1850   373  Male  Subadult       NaN        Yes       No           Cast  2003
# 1939   373  Male  Subadult       NaN        Yes      Yes         Active  2002
# 2034   373  Male  Subadult       NaN        Yes      Yes         Active  2001
# 2145   373  Male  Subadult       NaN         No      Yes         Active  2000

# %%
bearsRadio.query('Bear == 409')
# Out:
#       Bear     Sex       Age            Offspring Out of den Into den  \
# 2      409  Female     Adult  3 yearlings, 1 lost        Yes       No
# 114    409  Female     Adult               3 cubs        Yes      Yes
# 234    409  Female     Adult                  NaN         No      Yes
# 1965   409  Female  Subadult                  NaN         No       No
#
#      Current status  Year
# 2              Cast  2022
# 114          Active  2021
# 234          Active  2020
# 1965           Cast  2002

# %%
bearsRadio.query('Bear == 424')
# Out:
#       Bear   Sex       Age Offspring Out of den Into den Current status  Year
# 4      424  Male     Adult       NaN        Yes       No           Cast  2022
# 115    424  Male     Adult       NaN         No      Yes         Active  2021
# 1874   424  Male  Subadult       NaN        Yes       No           Cast  2003
# 1980   424  Male  Subadult       NaN         No      Yes         Active  2002

# %%
bearsRadio.query('Bear == 460')
# Out:
#       Bear   Sex       Age Offspring Out of den Into den Current status  Year
# 5      460  Male     Adult       NaN        Yes       No           Cast  2022
# 116    460  Male     Adult       NaN        Yes      Yes         Active  2021
# 236    460  Male     Adult       NaN         No      Yes         Active  2020
# 1590   460  Male  Subadult       NaN        Yes       No           Cast  2006
# 1687   460  Male  Subadult       NaN        Yes      Yes         Active  2005
# 1799   460  Male  Subadult       NaN         No      Yes         Active  2004

# %%
bearsRadio.query('Bear == 476')
# Out:
#       Bear     Sex    Age    Offspring Out of den Into den Current status  \
# 6      476  Female  Adult          NaN        Yes      Yes         Active
# 117    476  Female  Adult  1 cub, lost         No      Yes         Active
# 1496   476  Female  Adult   1 yearling        Yes       No     Unresolved
# 1595   476  Female  Adult        1 COY        Yes      Yes         Active
# 1701   476  Female  Adult          NaN        Yes      Yes         Active
# 1815   476  Female  Adult          NaN         No      Yes         Active
#
#       Year
# 6     2022
# 117   2021
# 1496  2007
# 1595  2006
# 1701  2005
# 1815  2004

# %%
pd.DataFrame(bearsRadio['Offspring'].value_counts())
# Out:
#                              count
# Offspring
# 2 yearlings                     50
# 2 COY                           50
# Not seen                        38
# 2 cubs                          28
# 1 yearling                      24
# ...                            ...
# 2 3-year-olds                    1
# 2 2-year-olds, weaned/lost?      1
# 1 yearling, weaned - GB 866      1
# 3 yearlings (1 - #900)           1
# 3 cubs of year                   1
#
# [111 rows x 1 columns]

# %%
pd.DataFrame(bearsRadio['Offspring'].value_counts()).plot(kind='bar', figsize=(20,10)) # Visual Representation of handler captures
# Out:
# <AxesSubplot:xlabel='Offspring'>

# %%
bearsRadio.loc[bearsRadio['Offspring'].isna(), 'Sex'].value_counts()
# Out:
# Sex
# Male      1285
# Female     485
# Name: count, dtype: int64
